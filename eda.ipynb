# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("C:/ASHHH/coding/student-risk-predictor/data/students.csv")
df.head()
# Out:
#    attendance  marks  assignments  sleep_hours  screen_time  stress_level  \
# 0          85     78           90            7            4             3
# 1          60     55           40            5            8             7
# 2          72     65           70            6            6             5
# 3          45     40           30            4            9             8
# 4          90     88           95            8            3             2
#
#    financial_pressure  dropout
# 0                   0        0
# 1                   1        1
# 2                   0        0
# 3                   1        1
# 4                   0        0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   attendance          10 non-null     int64
#  1   marks               10 non-null     int64
#  2   assignments         10 non-null     int64
#  3   sleep_hours         10 non-null     int64
#  4   screen_time         10 non-null     int64
#  5   stress_level        10 non-null     int64
#  6   financial_pressure  10 non-null     int64
#  7   dropout             10 non-null     int64
# dtypes: int64(8)
# memory usage: 772.0 bytes
#        attendance      marks  assignments  sleep_hours  screen_time  \
# count   10.000000  10.000000    10.000000    10.000000    10.000000
# mean    64.500000  59.100000    59.000000     5.700000     6.500000
# std     18.161314  17.897548    24.698178     1.337494     2.321398
# min     35.000000  30.000000    25.000000     4.000000     3.000000
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a modern theme
sns.set_theme(style="white")

plt.figure(figsize=(12,8))

# Create heatmap with enhancements
ax = sns.heatmap(
    df.corr(),
    annot=True,
    cmap="Spectral",       # vibrant modern colormap
    linewidths=0.5,        # thin lines between cells
    linecolor="white",
    cbar_kws={"shrink": 0.8, "aspect": 30},  # sleeker colorbar
    annot_kws={"size": 10, "weight": "bold"} # bold annotations
)

# Title styling
plt.title("📊 Feature Correlation Matrix", fontsize=18, fontweight="bold", pad=20)

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha="right", fontsize=11)
plt.yticks(fontsize=11)

# Tight layout for clean spacing
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18632\1923551539.py:28: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\ASHHH\coding\student-risk-predictor\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
